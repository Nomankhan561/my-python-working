# %%
nums = [1,2,3]
nums.append(10)
print(nums)
# Out:
# [1, 2, 3, 10]

# %%
order = ["burger","fries","coke"]
order.append("ice cream")
if "biryani" in order:
    order.remove("biryani")
    print("final order":",order)
    final order:['burger','fries','coke','ice cream']
# Out:
#   Cell In[8], line 5
#     print("final order":",order)
#                         ^
# SyntaxError: unterminated string literal (detected at line 5)

# %%
nums = [4,1,3,2]
nums.sort()
print(nums)
# Out:
# [1, 2, 3, 4]

# %%
passengers = ["ali","zara","ahmed"]
passengers.insert(2,"sara")
passengers.remove("zara")
passengers.reverse()
print(passengers)
# Out:
# ['ahmed', 'sara', 'ali']

# %%
word = "javascript"
print(len(word)>5)
# Out:
# True

# %%
product_code = "SKU-12345-XYZ"
first_dash = product_code.find("-")
dash_count = product_code.count("-")
numeric_part = product_code.replace("SKU-","").replace("-XYZ"-"")
print("First dash position:",first_dash)
print("Number of dashes:",dash_count)
print("numeric part:",numeric_part)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       2 first_dash = product_code.find("-")
#       3 dash_count = product_code.count("-")
# ----> 4 numeric_part = product_code.replace("SKU-","").replace("-XYZ"-"")
#       5 print("First dash position:",first_dash)
#       6 print("Number of dashes:",dash_count)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
text = "data analysis with python is very powerful"
text = text.strip()
text = text.replace("powerful","important")
print(text)
# Out:
# data analysis with python is very important

# %%
data = [12,45,2,67,34,89,23,90]
data.sort()
print(data)
# Out:
# [2, 12, 23, 34, 45, 67, 89, 90]

# %%
data.remove(max(data))
print(data)
# Out:
# [2, 12, 23, 34, 45, 67, 89]

# %%
data.insert(3,50)
print(data)
# Out:
# [2, 12, 23, 50, 34, 45, 67, 89]
