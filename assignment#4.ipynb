# %%
products = {
    101: {"name": "Laptop", "category": "Electronics", "price": 1200, "stock": 50},
    102: {"name": "Shirt", "category": "Apparel", "price": 25, "stock": 200},
    103: {"name": "Coffee Maker", "category": "Home Appliances", "price": 80, "stock": 30}
}
products[102]["stock"] = 250

print(products)

products[104] = {
    "name": "Smartphone",
    "category": "Electronics",
    "price": 800,
    "stock": 100
}

print(products)
# Out:
# {101: {'name': 'Laptop', 'category': 'Electronics', 'price': 1200, 'stock': 50}, 102: {'name': 'Shirt', 'category': 'Apparel', 'price': 25, 'stock': 250}, 103: {'name': 'Coffee Maker', 'category': 'Home Appliances', 'price': 80, 'stock': 30}}
# {101: {'name': 'Laptop', 'category': 'Electronics', 'price': 1200, 'stock': 50}, 102: {'name': 'Shirt', 'category': 'Apparel', 'price': 25, 'stock': 250}, 103: {'name': 'Coffee Maker', 'category': 'Home Appliances', 'price': 80, 'stock': 30}, 104: {'name': 'Smartphone', 'category': 'Electronics', 'price': 800, 'stock': 100}}

# %%
employee = ("Ali", 25, "Data Analyst", 75000)
name, age, job, salary = employee
updated_salary = salary * 1.10
print("Updated Salary:", updated_salary)
# Out:
# Updated Salary: 82500.0

# %%
shopping_list = ["apple", "banana", "apple", "orange", "banana", "grape"]
shopping_list = list(set(shopping_list))
print(shopping_list)
# Out:
# ['banana', 'grape', 'orange', 'apple']

# %%
numbers = (10, 20, 30, 40, 50, 60, 70)
print("First 3 elements:", numbers[:3])
print("Last 3 elements:", numbers[-3:])
print("Alternate elements:", numbers[::2])
# Out:
# First 3 elements: (10, 20, 30)
# Last 3 elements: (50, 60, 70)
# Alternate elements: (10, 30, 50, 70)

# %%
inventory = {
    "The Great Gatsby": {"price": 10.99, "quantity": 5},
    "Rich dad poor dad": {"price": 8.99, "quantity": 8},
    "Harry Potter": {"price": 12.50, "quantity": 2}
}
inventory.update({
    "Atomic Habits": {"price": 15.99, "quantity": 4}
})
print("Book Titles:", list(inventory.keys()))
inventory["Harry Potter"]["quantity"] = 0
if inventory["Harry Potter"]["quantity"] == 0:
    inventory.pop("Harry Potter")
print("Updated Inventory:")
print(inventory)
# Out:
# Book Titles: ['The Great Gatsby', 'Rich dad poor dad', 'Harry Potter', 'Atomic Habits']
# Updated Inventory:
# {'The Great Gatsby': {'price': 10.99, 'quantity': 5}, 'Rich dad poor dad': {'price': 8.99, 'quantity': 8}, 'Atomic Habits': {'price': 15.99, 'quantity': 4}}

# %%
d = {"x": 1, "y": 2}
for key, value in d.items():
    print(key, value)
# Out:
# x 1
# y 2

# %%
A = {"Ali", "Sara"}
B = {"Ahmed", "Zara"}
C = A.union(B)
print(C)
# Out:
# {'Sara', 'Ali', 'Zara', 'Ahmed'}

# %%
A = {1, 2, 3, 4, 5}
B = {4, 5, 6, 7}
print("Common elements:", A.intersection(B))
print("Only in Set A:", A.difference(B))
print("Only in Set B:", B.difference(A))
# Out:
# Common elements: {4, 5}
# Only in Set A: {1, 2, 3}
# Only in Set B: {6, 7}
